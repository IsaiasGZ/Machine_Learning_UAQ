# %%
import kagglehub
import os

# %% [markdown]
# # Proyecto Final
#
# ## Etapa 1. Analisis

# %%
os.environ["KAGGLEHUB_CACHE"] = "./Data/"
# Download latest version
path = kagglehub.dataset_download("sharmajicoder/student-mental-health-and-burnout")

print("Path to dataset files:", path)
# Out:
# Downloading to ./Data/datasets\sharmajicoder\student-mental-health-and-burnout\1.archive...
# 100%|██████████| 131M/131M [01:38<00:00, 1.40MB/s]
# Extracting files...
# Path to dataset files: ./Data/datasets\sharmajicoder\student-mental-health-and-burnout\versions\1
